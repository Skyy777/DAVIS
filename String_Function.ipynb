# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyy777/DAVIS/blob/main/String_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Skyy"
N = len(name)
print(N)
# Out:
# 4

# %%
age =22
T = type(age)
print(T)
# Out:
# <class 'int'>

# %%
msg = ("Hello, world!")
a= 10
b= 10
msg = msg + "The sum of x and y is: " + str(a+b)
print(msg)
# Out:
# Hello, world!The sum of x and y is: 20

# %% [markdown]
# String is set of characters enclosed with single , double , "triple" quotes.

# %%
name = "python"
print(name[2])
print(name[-2])
# Out:
# t
# o

# %% [markdown]
# String function

# %%
my_string = "Hello Colab"
string_length = len(my_string)
print(f"The string is: '{my_string}'")
print(f"The length of the string is: {string_length}")
# Out:
# The string is: 'Hello Colab'
# The length of the string is: 11

# %%
name = "python"
print(name.upper())
print(name.lower())
print(name.capitalize())
# Out:
# PYTHON
# python
# Python

# %%
name = "       hello world          "
print(name.strip())
print(name.lstrip())
print(name.rstrip())
print(name.split())
# Out:
# hello world
# hello world
#        hello world
# ['hello', 'world']

# %%
name = "hello"
print(name.replace("h","c"))
# Out:
# cello

# %%
name ="hello Sky"
print(name.find("Sky"))
# Out:
# 6

# %%
name = input("Enter your username: ")
name = name.replace(" ","")
username = '@'+name.lower()+str(len(name))

print(username)
# Out:
# Enter your username: Skyt
# @skyt4
