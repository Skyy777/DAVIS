# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyy777/DAVIS/blob/main/DAVIS_MCQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 try:

  num = int("abc")

 except ValueError:

  print("Invalid conversion.")

 else:

  print("Conversion successful.")
# Out:
# Invalid conversion.

# %%
 try:

  num = int(input("Enter a number: "))

 except ValueError:

  print("Invalid input. Please enter a number.")

 finally:

  print("Finally block executed.")
# Out:
# Enter a number: 1
# Finally block executed.

# %%
numbers = [1, 2, 3]

numbers.append(4)

print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
numbers = [1, 2, 3, 4, 5]

for num in numbers:

  if num == 3:

   continue

  print(num)
# Out:
# 1
# 2
# 4
# 5

# %%
try:

  raise ValueError("This is a custom exception.")
except Exception as e:

  print(type(e).__name__)
# Out:
# ValueError

# %%
try:

  num = int("42")

except ValueError:

  print("Invalid conversion.")

else:

  print("Conversion successful.")

finally:

  print("Finally block executed.")
# Out:
# Conversion successful.
# Finally block executed.

# %%
try:

 print(5 / 0)

except ZeroDivisionError:

 print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
try:

 raise ValueError("This is a custom exception.")

except Exception as e:

 print(type(e).__name__)
# Out:
# ValueError

# %%
numbers = [1, 2, 3, 4, 5]

for num in numbers:

 if num == 3:

  break

print(num)
# Out:
# 3

# %%
try:

  num = int("42")

except ValueError:

  print("Invalid conversion.")

else:

  print("Conversion successful.")

finally:

  print("Finally block executed.")
# Out:
# Conversion successful.
# Finally block executed.

# %%
fruits = ["apple", "banana", "cherry"]
for index, fruit in enumerate(fruits): print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
numbers = [1, 2, 3, 4, 5]

for num in numbers:
 if num % 2 == 0:

  print(num)
# Out:
# 2
# 4

# %%
 import numpy as np
 arr = np.arange(2, 10, 2)

print(arr)
# Out:
# [2 4 6 8]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

result = np.mean(arr)

print(result)
# Out:
# 3.5

# %%
import numpy as np
arr = np.array([1, 2, 3], dtype='float')
print(arr.dtype)
# Out:
# float64

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

result = np.max(arr)

print(result)
# Out:
# 6

# %%
arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

result = np.concatenate((arr1, arr2))

print(result)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as np

arr = np.array([1, 2, 3])

print(arr.shape)
# Out:
# (3,)

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

result = np.sum(arr)

print(result)
# Out:
# 21
